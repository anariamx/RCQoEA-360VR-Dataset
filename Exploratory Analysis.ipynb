# %% [markdown]
# # Ideias iniciais
# - Qoe contínuo prevê o Qoe pós vídeo?
#     - Usar o QoeC como vetor de input de uma rede neural para prever o QoeP e usar os resultados que temos para treinar e validar os valores de output
# - Correlação do ECG com Qoe Contínuo

# %% [markdown]
# # Objetivos
#
# - PT 1: Fazer JOIN das infos de Qoe Contínuo com as infos dos participantes
# - PT 2: Fazer JOIN das infos de Qoe Post Video com as infos dos participantes?
# - PT 3: Fazer JOIN da PT 1 com os dados de ECG
# - Checar mínimos, máximos, nulos, zeros, frequência, média, mediana, boxplots dos 3 datasets acima

# %% [markdown]
# # Bibliotecas

# %%
import numpy as np
